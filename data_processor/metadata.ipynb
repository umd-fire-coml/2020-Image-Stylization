# %%
import os
from PIL import Image
from PIL.ExifTags import TAGS

def print_metadata(fpath):
    im = Image.open(fpath)
    file_format = im.format
    image_mode = im.mode
    image_size = im.size
    color_palette = im.palette
    print("Attributes of image:%s"%fpath)
    print("The file format of the image is:%s"%file_format)
    print("The mode of the image is:%s"%image_mode)
    print("The size of the image is:width %d pixels,height %d pixels"%image_size)
    print("Color palette used in image:%s"%color_palette)
    print("File Size In Bytes:- "+str(len(im.fp.read())))
    print("\n")

# %%
inputs = os.listdir('../data')
number_files = len(inputs)

#then, iterate through & display
for i in range(1, number_files+1):
    input_image = '../data/in'+str(i)+'.png'
    print_metadata(input_image)
    #style_image = './data/style/tar'+str(i)+'.png'
    #print_metadata(style_image)
# Out:
# Attributes of image:../data/in1.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 437 pixels
# Color palette used in image:None
# File Size In Bytes:- 415661
#
#
# Attributes of image:../data/in2.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 394 pixels
# Color palette used in image:None
# File Size In Bytes:- 149060
#
#
# Attributes of image:../data/in3.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 468 pixels
# Color palette used in image:None
# File Size In Bytes:- 557529
#
#
# Attributes of image:../data/in4.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 468 pixels
# Color palette used in image:None
# File Size In Bytes:- 557529
#
#
# Attributes of image:../data/in5.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 438249
#
#
# Attributes of image:../data/in6.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 394 pixels
# Color palette used in image:None
# File Size In Bytes:- 440469
#
#
# Attributes of image:../data/in7.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 394 pixels
# Color palette used in image:None
# File Size In Bytes:- 364757
#
#
# Attributes of image:../data/in8.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 463 pixels
# Color palette used in image:None
# File Size In Bytes:- 310952
#
#
# Attributes of image:../data/in9.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 467 pixels
# Color palette used in image:None
# File Size In Bytes:- 362486
#
#
# Attributes of image:../data/in10.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 373 pixels
# Color palette used in image:None
# File Size In Bytes:- 457078
#
#
# Attributes of image:../data/in11.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 530 pixels,height 700 pixels
# Color palette used in image:None
# File Size In Bytes:- 463981
#
#
# Attributes of image:../data/in12.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 530 pixels,height 700 pixels
# Color palette used in image:None
# File Size In Bytes:- 463981
#
#
# Attributes of image:../data/in13.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 503851
#
#
# Attributes of image:../data/in14.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 478297
#
#
# Attributes of image:../data/in15.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 472676
#
#
# Attributes of image:../data/in16.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 188382
#
#
# Attributes of image:../data/in17.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 393 pixels
# Color palette used in image:None
# File Size In Bytes:- 422925
#
#
# Attributes of image:../data/in18.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 437 pixels,height 700 pixels
# Color palette used in image:None
# File Size In Bytes:- 267138
#
#
# Attributes of image:../data/in19.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 437 pixels
# Color palette used in image:None
# File Size In Bytes:- 474475
#
#
# Attributes of image:../data/in20.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 601648
#
#
# Attributes of image:../data/in21.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 669332
#
#
# Attributes of image:../data/in22.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 467 pixels
# Color palette used in image:None
# File Size In Bytes:- 362486
#
#
# Attributes of image:../data/in23.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 390 pixels
# Color palette used in image:None
# File Size In Bytes:- 362254
#
#
# Attributes of image:../data/in24.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 669332
#
#
# Attributes of image:../data/in25.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 500 pixels
# Color palette used in image:None
# File Size In Bytes:- 503535
#
#
# Attributes of image:../data/in26.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 523 pixels
# Color palette used in image:None
# File Size In Bytes:- 493477
#
#
# Attributes of image:../data/in27.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 543 pixels
# Color palette used in image:None
# File Size In Bytes:- 577361
#
#
# Attributes of image:../data/in28.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 427 pixels
# Color palette used in image:None
# File Size In Bytes:- 179801
#
#
# Attributes of image:../data/in29.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 393 pixels
# Color palette used in image:None
# File Size In Bytes:- 418545
#
#
# Attributes of image:../data/in30.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 609715
#
#
# Attributes of image:../data/in31.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 468 pixels
# Color palette used in image:None
# File Size In Bytes:- 463239
#
#
# Attributes of image:../data/in32.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 437 pixels
# Color palette used in image:None
# File Size In Bytes:- 411137
#
#
# Attributes of image:../data/in33.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 700 pixels
# Color palette used in image:None
# File Size In Bytes:- 137960
#
#
# Attributes of image:../data/in34.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 486 pixels
# Color palette used in image:None
# File Size In Bytes:- 500788
#
#
# Attributes of image:../data/in35.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 473583
#
#
# Attributes of image:../data/in36.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 597 pixels
# Color palette used in image:None
# File Size In Bytes:- 256334
#
#
# Attributes of image:../data/in37.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 420 pixels
# Color palette used in image:None
# File Size In Bytes:- 341089
#
#
# Attributes of image:../data/in38.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 275027
#
#
# Attributes of image:../data/in39.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 581239
#
#
# Attributes of image:../data/in40.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 465 pixels
# Color palette used in image:None
# File Size In Bytes:- 419672
#
#
# Attributes of image:../data/in41.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 565806
#
#
# Attributes of image:../data/in42.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 497074
#
#
# Attributes of image:../data/in43.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 587043
#
#
# Attributes of image:../data/in44.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 312247
#
#
# Attributes of image:../data/in45.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 651 pixels
# Color palette used in image:None
# File Size In Bytes:- 506885
#
#
# Attributes of image:../data/in46.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 518 pixels
# Color palette used in image:None
# File Size In Bytes:- 482609
#
#
# Attributes of image:../data/in47.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 386029
#
#
# Attributes of image:../data/in48.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 363 pixels
# Color palette used in image:None
# File Size In Bytes:- 346079
#
#
# Attributes of image:../data/in49.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 363 pixels
# Color palette used in image:None
# File Size In Bytes:- 346079
#
#
# Attributes of image:../data/in50.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 393 pixels
# Color palette used in image:None
# File Size In Bytes:- 500638
#
#
# Attributes of image:../data/in51.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 468 pixels
# Color palette used in image:None
# File Size In Bytes:- 677479
#
#
# Attributes of image:../data/in52.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 761466
#
#
# Attributes of image:../data/in53.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 474400
#
#
# Attributes of image:../data/in54.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 746212
#
#
# Attributes of image:../data/in55.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 395897
#
#
# Attributes of image:../data/in56.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 456 pixels
# Color palette used in image:None
# File Size In Bytes:- 454162
#
#
# Attributes of image:../data/in57.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 460 pixels
# Color palette used in image:None
# File Size In Bytes:- 738904
#
#
# Attributes of image:../data/in58.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 525 pixels
# Color palette used in image:None
# File Size In Bytes:- 475272
#
#
# Attributes of image:../data/in59.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 528 pixels
# Color palette used in image:None
# File Size In Bytes:- 456376
#
#
# Attributes of image:../data/in60.png
# The file format of the image is:PNG
# The mode of the image is:RGB
# The size of the image is:width 700 pixels,height 466 pixels
# Color palette used in image:None
# File Size In Bytes:- 509078
